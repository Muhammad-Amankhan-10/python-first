# %%
import time

print("Welcome to the Magic Math Game!")
time.sleep(1)
print("SUCHO 1 and 10 TAK (but don't tell me).")
input("Enter daba dena jab suchlo...")

print("\nFollow these steps carefully:")
time.sleep(1)
print("1️⃣ Multiply your number by 2.")
input("Done? Press Enter...")
print("2️⃣ Add 4 to the result.")
input("Done? Press Enter...")
print("3️⃣ Divide the result by 2.")
input("Done? Press Enter...")
print("4️⃣ Subtract your original number from the result.")
input("Done? Press Enter...")

print("\nLet me think...")
time.sleep(2)
print("Calculating the magic... 🪄")
time.sleep(2)
print("The result you have now is... 2!")

time.sleep(1)
print("Amazing, right? You always end up with 2!")
# Out:
# Welcome to the Magic Math Game!
# SUCHO 1 and 10 TAK (but don't tell me).
#
# Follow these steps carefully:
# 1️⃣ Multiply your number by 2.
# 2️⃣ Add 4 to the result.
# 3️⃣ Divide the result by 2.

# %%
print("Think of a number between 1 and 100.")

input("Press Enter when ready...")

print("Step 1: Add 5 to your number.")
input("Press Enter when done...")

print("Step 2: Multiply the result by 2.")
input("Press Enter when done...")

print("Step 3: Subtract 10 from the result.")
input("Press Enter when done...")

final = int(input("Ab mujhy final result batao: "))

original = final // 2

print("\nLet me guess your original number...")
print("🧠 Calculating...")
print(f"Your original number was: {original} 😎")
# Out:
# Think of a number between 1 and 100.
# Step 1: Add 5 to your number.
# Step 2: Multiply the result by 2.
# Step 3: Subtract 10 from the result.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 14
#      11 print("Step 3: Subtract 10 from the result.")
#      12 input("Press Enter when done...")
# ---> 14 final = int(input("Ab mujhy final result batao: "))
#      16 original = final // 2
#      18 print("\nLet me guess your original number...")
#
# ValueError: invalid literal for int() with base 10: ''
