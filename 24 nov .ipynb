# %%
with open("student_result.txt", "w") as w:
    w.write("hello world")

# %%
with open("student_result.txt") as t:
    print(t.read())
# Out:
# hello world

# %%
num = int(input("Enter table number: "))

with open("multiplication_table.txt", "a") as a:

    for i in range(1, 11):
        a.write(f"{num} x {i} = {num * i}\n")
